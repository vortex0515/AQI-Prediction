# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Downloads/mumbai-aqi-data-2010-2020.csv")

# %%
data.shape
# Out:
# (9570, 1)

# %%
data = pd.read_csv("Downloads/mumbai-aqi-data-2010-2020.csv", delimiter=';')

# %%
data.shape
# Out:
# (9570, 36)

# %%
data.head()
# Out:
#      city                            site_name       site        state  \
# 0  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 1  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 2  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 3  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 4  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
#
#                                    query_name      to_date to_time  \
# 0  run2_maharashtra_mumbai_site_5392_20201104  05-Nov-2020   00:00
# 1  run2_maharashtra_mumbai_site_5392_20201104  06-Nov-2020   00:00
# 2  run2_maharashtra_mumbai_site_5392_20201104  07-Nov-2020   00:00
# 3  run2_maharashtra_mumbai_site_5392_20201104  08-Nov-2020   00:00
# 4  run2_maharashtra_mumbai_site_5392_20201104  09-Nov-2020   00:00
#
#      from_date from_time  PM2.5  ...  AT  TOT-RF  RF  Xylene  WS  O Xylene  \
# 0  04-Nov-2020     00:00    NaN  ... NaN     0.0 NaN     NaN NaN       NaN
# 1  05-Nov-2020     00:00    NaN  ... NaN     0.0 NaN     NaN NaN       NaN
# 2  06-Nov-2020     00:00    NaN  ... NaN     0.0 NaN     NaN NaN       NaN
# 3  07-Nov-2020     00:00    NaN  ... NaN     0.0 NaN     NaN NaN       NaN
# 4  08-Nov-2020     00:00    NaN  ... NaN     0.0 NaN     NaN NaN       NaN
#
#    Temp  P-Xylene  VWS  Rack Temp
# 0   NaN       NaN  NaN        NaN
# 1   NaN       NaN  NaN        NaN
# 2   NaN       NaN  NaN        NaN
# 3   NaN       NaN  NaN        NaN
# 4   NaN       NaN  NaN        NaN
#
# [5 rows x 36 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9570 entries, 0 to 9569
# Data columns (total 36 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         9570 non-null   object
#  1   site_name    9570 non-null   object
#  2   site         9570 non-null   object
#  3   state        9570 non-null   object
#  4   query_name   9570 non-null   object
#  5   to_date      9570 non-null   object
#  6   to_time      9570 non-null   object
#  7   from_date    9570 non-null   object
#  8   from_time    9570 non-null   object
#  9   PM2.5        5964 non-null   float64
#  10  PM10         5826 non-null   float64
#  11  NO           6175 non-null   float64
#  12  NO2          6170 non-null   float64
#  13  NOx          7537 non-null   float64
#  14  NH3          5235 non-null   float64
#  15  SO2          5930 non-null   float64
#  16  CO           7952 non-null   float64
#  17  Ozone        6011 non-null   float64
#  18  Benzene      7509 non-null   float64
#  19  Toluene      2779 non-null   float64
#  20  Eth-Benzene  5893 non-null   float64
#  21  MP-Xylene    4849 non-null   float64
#  22  RH           6029 non-null   float64
#  23  WD           6043 non-null   float64
#  24  SR           5169 non-null   float64
#  25  BP           2723 non-null   float64
#  26  AT           5514 non-null   float64
#  27  TOT-RF       9570 non-null   float64
#  28  RF           1784 non-null   float64
#  29  Xylene       1263 non-null   float64
#  30  WS           6039 non-null   float64
#  31  O Xylene     0 non-null      float64
#  32  Temp         0 non-null      float64
#  33  P-Xylene     0 non-null      float64
#  34  VWS          0 non-null      float64
#  35  Rack Temp    0 non-null      float64
# dtypes: float64(27), object(9)
# memory usage: 2.6+ MB

# %%
data.columns
# Out:
# Index(['city', 'site_name', 'site', 'state', 'query_name', 'to_date',
#        'to_time', 'from_date', 'from_time', 'PM2.5', 'PM10', 'NO', 'NO2',
#        'NOx', 'NH3', 'SO2', 'CO', 'Ozone', 'Benzene', 'Toluene', 'Eth-Benzene',
#        'MP-Xylene', 'RH', 'WD', 'SR', 'BP', 'AT', 'TOT-RF', 'RF', 'Xylene',
#        'WS', 'O Xylene', 'Temp', 'P-Xylene', 'VWS', 'Rack Temp'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# city              0
# site_name         0
# site              0
# state             0
# query_name        0
# to_date           0
# to_time           0
# from_date         0
# from_time         0
# PM2.5          3606
# PM10           3744
# NO             3395
# NO2            3400
# NOx            2033
# NH3            4335
# SO2            3640
# CO             1618
# Ozone          3559
# Benzene        2061
# Toluene        6791
# Eth-Benzene    3677
# MP-Xylene      4721
# RH             3541
# WD             3527
# SR             4401
# BP             6847
# AT             4056
# TOT-RF            0
# RF             7786
# Xylene         8307
# WS             3531
# O Xylene       9570
# Temp           9570
# P-Xylene       9570
# VWS            9570
# Rack Temp      9570
# dtype: int64

# %%
data.isnull().sum()*100/data.shape[0]
# Out:
# city             0.000000
# site_name        0.000000
# site             0.000000
# state            0.000000
# query_name       0.000000
# to_date          0.000000
# to_time          0.000000
# from_date        0.000000
# from_time        0.000000
# PM2.5           37.680251
# PM10            39.122257
# NO              35.475444
# NO2             35.527691
# NOx             21.243469
# NH3             45.297806
# SO2             38.035528
# CO              16.907001
# Ozone           37.189133
# Benzene         21.536050
# Toluene         70.961338
# Eth-Benzene     38.422153
# MP-Xylene       49.331243
# RH              37.001045
# WD              36.854754
# SR              45.987461
# BP              71.546499
# AT              42.382445
# TOT-RF           0.000000
# RF              81.358412
# Xylene          86.802508
# WS              36.896552
# O Xylene       100.000000
# Temp           100.000000
# P-Xylene       100.000000
# VWS            100.000000
# Rack Temp      100.000000
# dtype: float64

# %%
data.isnull().sum().sum()
# Out:
# 136426

# %%
data.isnull().sum().sum()/(data.shape[0]*data.shape[1])*100
# Out:
# 39.59886218506908

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
en_data = data.dropna()

# %%
en_data.isnull().sum()/data.shape[0]*100
# Out:
# city           0.0
# site_name      0.0
# site           0.0
# state          0.0
# query_name     0.0
# to_date        0.0
# to_time        0.0
# from_date      0.0
# from_time      0.0
# PM2.5          0.0
# PM10           0.0
# NO             0.0
# NO2            0.0
# NOx            0.0
# NH3            0.0
# SO2            0.0
# CO             0.0
# Ozone          0.0
# Benzene        0.0
# Toluene        0.0
# Eth-Benzene    0.0
# MP-Xylene      0.0
# RH             0.0
# WD             0.0
# SR             0.0
# BP             0.0
# AT             0.0
# TOT-RF         0.0
# RF             0.0
# Xylene         0.0
# WS             0.0
# O Xylene       0.0
# Temp           0.0
# P-Xylene       0.0
# VWS            0.0
# Rack Temp      0.0
# dtype: float64

# %%
en_data.shape
# Out:
# (0, 36)

# %%
dataset = data[["city", "site_name", "site", "state", "query_name", "to_date", "to_time", "from_date", "from_time", "PM2.5", "PM10", "NO", "NO2", "NOx", "NH3", "SO2", "CO", "Ozone"]]

# %%
dataset.head()
# Out:
#      city                            site_name       site        state  \
# 0  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 1  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 2  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 3  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
# 4  Mumbai  Bandra Kurla Complex, Mumbai - IITM  site_5392  Maharashtra
#
#                                    query_name      to_date to_time  \
# 0  run2_maharashtra_mumbai_site_5392_20201104  05-Nov-2020   00:00
# 1  run2_maharashtra_mumbai_site_5392_20201104  06-Nov-2020   00:00
# 2  run2_maharashtra_mumbai_site_5392_20201104  07-Nov-2020   00:00
# 3  run2_maharashtra_mumbai_site_5392_20201104  08-Nov-2020   00:00
# 4  run2_maharashtra_mumbai_site_5392_20201104  09-Nov-2020   00:00
#
#      from_date from_time  PM2.5  PM10  NO  NO2  NOx  NH3  SO2  CO  Ozone
# 0  04-Nov-2020     00:00    NaN   NaN NaN  NaN  NaN  NaN  NaN NaN    NaN
# 1  05-Nov-2020     00:00    NaN   NaN NaN  NaN  NaN  NaN  NaN NaN    NaN
# 2  06-Nov-2020     00:00    NaN   NaN NaN  NaN  NaN  NaN  NaN NaN    NaN
# 3  07-Nov-2020     00:00    NaN   NaN NaN  NaN  NaN  NaN  NaN NaN    NaN
# 4  08-Nov-2020     00:00    NaN   NaN NaN  NaN  NaN  NaN  NaN NaN    NaN

# %%
dataset.shape
# Out:
# (9570, 18)

# %%
dataset.columns
# Out:
# Index(['city', 'site_name', 'site', 'state', 'query_name', 'to_date',
#        'to_time', 'from_date', 'from_time', 'PM2.5', 'PM10', 'NO', 'NO2',
#        'NOx', 'NH3', 'SO2', 'CO', 'Ozone'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9570 entries, 0 to 9569
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        9570 non-null   object
#  1   site_name   9570 non-null   object
#  2   site        9570 non-null   object
#  3   state       9570 non-null   object
#  4   query_name  9570 non-null   object
#  5   to_date     9570 non-null   object
#  6   to_time     9570 non-null   object
#  7   from_date   9570 non-null   object
#  8   from_time   9570 non-null   object
#  9   PM2.5       5964 non-null   float64
#  10  PM10        5826 non-null   float64
#  11  NO          6175 non-null   float64
#  12  NO2         6170 non-null   float64
#  13  NOx         7537 non-null   float64
#  14  NH3         5235 non-null   float64
#  15  SO2         5930 non-null   float64
#  16  CO          7952 non-null   float64
#  17  Ozone       6011 non-null   float64
# dtypes: float64(9), object(9)
# memory usage: 1.3+ MB

# %%
dataset.isnull().sum()/dataset.shape[0]*100
# Out:
# city           0.000000
# site_name      0.000000
# site           0.000000
# state          0.000000
# query_name     0.000000
# to_date        0.000000
# to_time        0.000000
# from_date      0.000000
# from_time      0.000000
# PM2.5         37.680251
# PM10          39.122257
# NO            35.475444
# NO2           35.527691
# NOx           21.243469
# NH3           45.297806
# SO2           38.035528
# CO            16.907001
# Ozone         37.189133
# dtype: float64

# %%
en_data = dataset.dropna()

# %%
en_data.shape
# Out:
# (4523, 18)

# %%
en_data.isnull().sum()/en_data.shape[0]*100
# Out:
# city          0.0
# site_name     0.0
# site          0.0
# state         0.0
# query_name    0.0
# to_date       0.0
# to_time       0.0
# from_date     0.0
# from_time     0.0
# PM2.5         0.0
# PM10          0.0
# NO            0.0
# NO2           0.0
# NOx           0.0
# NH3           0.0
# SO2           0.0
# CO            0.0
# Ozone         0.0
# dtype: float64

# %%
# pecentage of info removed
((dataset.shape[0]-en_data.shape[0])/dataset.shape[0])*100
# Out:
# 52.73772204806687

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.bfill(inplace=True)
# Out:
# C:\Users\Lipika Priya\AppData\Local\Temp\ipykernel_7672\1965104898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.bfill(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# city          0
# site_name     0
# site          0
# state         0
# query_name    0
# to_date       0
# to_time       0
# from_date     0
# from_time     0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           1
# SO2           0
# CO            0
# Ozone         0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.ffill(inplace=True)
# Out:
# C:\Users\Lipika Priya\AppData\Local\Temp\ipykernel_7672\606270558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.ffill(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# city          0
# site_name     0
# site          0
# state         0
# query_name    0
# to_date       0
# to_time       0
# from_date     0
# from_time     0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# SO2           0
# CO            0
# Ozone         0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
pollutants = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'SO2', 'CO', 'Ozone']

# Group the data by 'site_name' and take the mean of pollutants
grouped_data = dataset.groupby('site_name')[pollutants].mean()

# Set up the figure for plotting
plt.figure(figsize=(16, 8))

# Define bar width (kept the same)
bar_width = 0.8

# Plot grouped bar chart with additional space between bars
grouped_data.plot(kind='bar', width=bar_width, figsize=(16, 8), position=1)

# Adjust x-ticks to space them further apart
plt.xticks(range(len(grouped_data)), grouped_data.index, rotation=45, ha='right')

# Add chart details
plt.title('Pollutant Concentrations by Site Name', fontsize=16)
plt.ylabel('Concentration (µg/m³)', fontsize=12)
plt.xlabel('Site Name', fontsize=12)
plt.legend(title='Pollutants', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust legend location
plt.tight_layout()

# Show the plot
plt.show()
