# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Downloads/chennai-aqi-data-2010-2020.csv")

# %%
data.shape
# Out:
# (12400, 1)

# %%
data = pd.read_csv("Downloads/chennai-aqi-data-2010-2020.csv", delimiter=';')

# %%
data.head()
# Out:
#       city                          site_name      site       state  \
# 0  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 1  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 2  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 3  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 4  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
#
#                                  query_name      to_date to_time    from_date  \
# 0  run2_tamilnadu_chennai_site_293_20100101  02-Jan-2010   00:00  01-Jan-2010
# 1  run2_tamilnadu_chennai_site_293_20100101  03-Jan-2010   00:00  02-Jan-2010
# 2  run2_tamilnadu_chennai_site_293_20100101  04-Jan-2010   00:00  03-Jan-2010
# 3  run2_tamilnadu_chennai_site_293_20100101  05-Jan-2010   00:00  04-Jan-2010
# 4  run2_tamilnadu_chennai_site_293_20100101  06-Jan-2010   00:00  05-Jan-2010
#
#   from_time  PM2.5  ...  AT  TOT-RF  RF  Xylene    WS  O Xylene   Temp  \
# 0     00:00    NaN  ... NaN     NaN NaN     NaN  1.08       NaN  27.39
# 1     00:00    NaN  ... NaN     NaN NaN     NaN  1.22       NaN  27.42
# 2     00:00    NaN  ... NaN     NaN NaN     NaN  1.16       NaN  27.28
# 3     00:00    NaN  ... NaN     NaN NaN     NaN  0.92       NaN  25.83
# 4     00:00    NaN  ... NaN     NaN NaN     NaN  0.93       NaN  25.38
#
#    P-Xylene   VWS  Rack Temp
# 0       NaN  0.57        NaN
# 1       NaN  0.58        NaN
# 2       NaN  0.57        NaN
# 3       NaN  0.56        NaN
# 4       NaN  0.56        NaN
#
# [5 rows x 36 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12400 entries, 0 to 12399
# Data columns (total 36 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         12400 non-null  object
#  1   site_name    12400 non-null  object
#  2   site         12400 non-null  object
#  3   state        12400 non-null  object
#  4   query_name   12400 non-null  object
#  5   to_date      12400 non-null  object
#  6   to_time      12400 non-null  object
#  7   from_date    12400 non-null  object
#  8   from_time    12400 non-null  object
#  9   PM2.5        6257 non-null   float64
#  10  PM10         729 non-null    float64
#  11  NO           10787 non-null  float64
#  12  NO2          10475 non-null  float64
#  13  NOx          9987 non-null   float64
#  14  NH3          3768 non-null   float64
#  15  SO2          9496 non-null   float64
#  16  CO           7663 non-null   float64
#  17  Ozone        6902 non-null   float64
#  18  Benzene      4354 non-null   float64
#  19  Toluene      4402 non-null   float64
#  20  Eth-Benzene  2340 non-null   float64
#  21  MP-Xylene    2244 non-null   float64
#  22  RH           9592 non-null   float64
#  23  WD           10158 non-null  float64
#  24  SR           9049 non-null   float64
#  25  BP           8337 non-null   float64
#  26  AT           0 non-null      float64
#  27  TOT-RF       0 non-null      float64
#  28  RF           0 non-null      float64
#  29  Xylene       0 non-null      float64
#  30  WS           9617 non-null   float64
#  31  O Xylene     3709 non-null   float64
#  32  Temp         6024 non-null   float64
#  33  P-Xylene     0 non-null      float64
#  34  VWS          8760 non-null   float64
#  35  Rack Temp    0 non-null      float64
# dtypes: float64(27), object(9)
# memory usage: 3.4+ MB

# %%
data.shape
# Out:
# (12400, 36)

# %%
data.columns
# Out:
# Index(['city', 'site_name', 'site', 'state', 'query_name', 'to_date',
#        'to_time', 'from_date', 'from_time', 'PM2.5', 'PM10', 'NO', 'NO2',
#        'NOx', 'NH3', 'SO2', 'CO', 'Ozone', 'Benzene', 'Toluene', 'Eth-Benzene',
#        'MP-Xylene', 'RH', 'WD', 'SR', 'BP', 'AT', 'TOT-RF', 'RF', 'Xylene',
#        'WS', 'O Xylene', 'Temp', 'P-Xylene', 'VWS', 'Rack Temp'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# city               0
# site_name          0
# site               0
# state              0
# query_name         0
# to_date            0
# to_time            0
# from_date          0
# from_time          0
# PM2.5           6143
# PM10           11671
# NO              1613
# NO2             1925
# NOx             2413
# NH3             8632
# SO2             2904
# CO              4737
# Ozone           5498
# Benzene         8046
# Toluene         7998
# Eth-Benzene    10060
# MP-Xylene      10156
# RH              2808
# WD              2242
# SR              3351
# BP              4063
# AT             12400
# TOT-RF         12400
# RF             12400
# Xylene         12400
# WS              2783
# O Xylene        8691
# Temp            6376
# P-Xylene       12400
# VWS             3640
# Rack Temp      12400
# dtype: int64

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# city             0.000000
# site_name        0.000000
# site             0.000000
# state            0.000000
# query_name       0.000000
# to_date          0.000000
# to_time          0.000000
# from_date        0.000000
# from_time        0.000000
# PM2.5           49.540323
# PM10            94.120968
# NO              13.008065
# NO2             15.524194
# NOx             19.459677
# NH3             69.612903
# SO2             23.419355
# CO              38.201613
# Ozone           44.338710
# Benzene         64.887097
# Toluene         64.500000
# Eth-Benzene     81.129032
# MP-Xylene       81.903226
# RH              22.645161
# WD              18.080645
# SR              27.024194
# BP              32.766129
# AT             100.000000
# TOT-RF         100.000000
# RF             100.000000
# Xylene         100.000000
# WS              22.443548
# O Xylene        70.088710
# Temp            51.419355
# P-Xylene       100.000000
# VWS             29.354839
# Rack Temp      100.000000
# dtype: float64

# %%
data.isnull().sum().sum()
# Out:
# 190150

# %%
data.isnull().sum().sum()/(data.shape[0]*data.shape[1])*100
# Out:
# 42.596326164874554

# %%
dataset = data[["city", "site_name", "site", "state", "query_name", "to_date", "to_time", "from_date", "from_time", "PM2.5", "PM10", "NO", "NO2", "NOx", "NH3", "SO2", "CO", "Ozone"]]

# %%
dataset.head()
# Out:
#       city                          site_name      site       state  \
# 0  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 1  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 2  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 3  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
# 4  Chennai  Alandur Bus Depot, Chennai - CPCB  site_293  Tamil Nadu
#
#                                  query_name      to_date to_time    from_date  \
# 0  run2_tamilnadu_chennai_site_293_20100101  02-Jan-2010   00:00  01-Jan-2010
# 1  run2_tamilnadu_chennai_site_293_20100101  03-Jan-2010   00:00  02-Jan-2010
# 2  run2_tamilnadu_chennai_site_293_20100101  04-Jan-2010   00:00  03-Jan-2010
# 3  run2_tamilnadu_chennai_site_293_20100101  05-Jan-2010   00:00  04-Jan-2010
# 4  run2_tamilnadu_chennai_site_293_20100101  06-Jan-2010   00:00  05-Jan-2010
#
#   from_time  PM2.5  PM10     NO    NO2     NOx  NH3    SO2    CO  Ozone
# 0     00:00    NaN   NaN  24.65  59.05   83.71  NaN   5.87  1.34  13.75
# 1     00:00    NaN   NaN  14.33  42.58   56.91  NaN   4.86  1.36  15.64
# 2     00:00    NaN   NaN  19.59  41.04   60.59  NaN   5.43  1.72  23.53
# 3     00:00    NaN   NaN  39.66  85.54  125.20  NaN  10.78  2.39  15.16
# 4     00:00    NaN   NaN  38.11  94.57  132.68  NaN   5.74  0.98  10.57

# %%
dataset.shape
# Out:
# (12400, 18)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12400 entries, 0 to 12399
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        12400 non-null  object
#  1   site_name   12400 non-null  object
#  2   site        12400 non-null  object
#  3   state       12400 non-null  object
#  4   query_name  12400 non-null  object
#  5   to_date     12400 non-null  object
#  6   to_time     12400 non-null  object
#  7   from_date   12400 non-null  object
#  8   from_time   12400 non-null  object
#  9   PM2.5       6257 non-null   float64
#  10  PM10        729 non-null    float64
#  11  NO          10787 non-null  float64
#  12  NO2         10475 non-null  float64
#  13  NOx         9987 non-null   float64
#  14  NH3         3768 non-null   float64
#  15  SO2         9496 non-null   float64
#  16  CO          7663 non-null   float64
#  17  Ozone       6902 non-null   float64
# dtypes: float64(9), object(9)
# memory usage: 1.7+ MB

# %%
dataset.columns
# Out:
# Index(['city', 'site_name', 'site', 'state', 'query_name', 'to_date',
#        'to_time', 'from_date', 'from_time', 'PM2.5', 'PM10', 'NO', 'NO2',
#        'NOx', 'NH3', 'SO2', 'CO', 'Ozone'],
#       dtype='object')

# %%
dataset.isnull().sum()/dataset.shape[0]*100
# Out:
# city           0.000000
# site_name      0.000000
# site           0.000000
# state          0.000000
# query_name     0.000000
# to_date        0.000000
# to_time        0.000000
# from_date      0.000000
# from_time      0.000000
# PM2.5         49.540323
# PM10          94.120968
# NO            13.008065
# NO2           15.524194
# NOx           19.459677
# NH3           69.612903
# SO2           23.419355
# CO            38.201613
# Ozone         44.338710
# dtype: float64

# %%
dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1])*100
# Out:
# 20.40143369175627

# %%
en_data = dataset.dropna()

# %%
en_data.isnull().sum()
# Out:
# city          0
# site_name     0
# site          0
# state         0
# query_name    0
# to_date       0
# to_time       0
# from_date     0
# from_time     0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# SO2           0
# CO            0
# Ozone         0
# dtype: int64

# %%
en_data.shape
# Out:
# (649, 18)

# %%
# % of loss of data
(dataset.shape[0]-en_data.shape[0])/dataset.shape[0]*100
# Out:
# 94.76612903225806

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
dataset.bfill(inplace=True)
# Out:
# C:\Users\Lipika Priya\AppData\Local\Temp\ipykernel_564\1965104898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.bfill(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# city             0
# site_name        0
# site             0
# state            0
# query_name       0
# to_date          0
# to_time          0
# from_date        0
# from_time        0
# PM2.5            0
# PM10          3930
# NO               0
# NO2              0
# NOx              0
# NH3           3930
# SO2              0
# CO               0
# Ozone            0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.ffill(inplace=True)
# Out:
# C:\Users\Lipika Priya\AppData\Local\Temp\ipykernel_564\606270558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.ffill(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# city          0
# site_name     0
# site          0
# state         0
# query_name    0
# to_date       0
# to_time       0
# from_date     0
# from_time     0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# SO2           0
# CO            0
# Ozone         0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
pollutants = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'SO2', 'CO', 'Ozone']

# Group the data by 'site_name' and take the mean of pollutants
grouped_data = dataset.groupby('site_name')[pollutants].mean()

# Set up the figure for plotting
plt.figure(figsize=(16, 8))

# Define bar width (kept the same)
bar_width = 0.8

# Plot grouped bar chart with additional space between bars
grouped_data.plot(kind='bar', width=bar_width, figsize=(16, 8), position=1)

# Adjust x-ticks to space them further apart
plt.xticks(range(len(grouped_data)), grouped_data.index, rotation=45, ha='right')

# Add chart details
plt.title('Pollutant Concentrations by Site Name', fontsize=16)
plt.ylabel('Concentration (µg/m³)', fontsize=12)
plt.xlabel('Site Name', fontsize=12)
plt.legend(title='Pollutants', bbox_to_anchor=(1.05, 1), loc='upper left')  # Adjust legend location
plt.tight_layout()

# Show the plot
plt.show()
